# %% [markdown]
# # Fine-tune Llama 3.1 8B with Unsloth
# > 🗣️ [Large Language Model Course](https://github.com/mlabonne/llm-course)
#
# ❤️ Created by [@maximelabonne](https://twitter.com/maximelabonne).
#
# URL: https://huggingface.co/blog/mlabonne/sft-llama3

# %%
# python -m venv .venv1
# . .\.venv1\Scripts\activate
# pip install jupyter

# %%
import sys
print(sys.executable)
# Out:
# e:\_SFT\_src\.venv1\Scripts\python.exe

# %%
# !pip install --no-deps "protobuf>=4.25.2"
# Out:
# Requirement already satisfied: protobuf>=4.25.2 in e:\_sft\_src\.venv1\lib\site-packages (5.29.3)

# %%
 #pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in e:\_sft\_src\.venv1\lib\site-packages (24.2)
# Collecting pip
#   Using cached pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Using cached pip-25.0.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
# Successfully installed pip-25.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -qqq "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git" --progress-bar off
from torch import __version__; from packaging.version import Version as V
xformers = "xformers==0.0.27" if V(__version__) < V("2.4.0") else "xformers"
# !pip install -qqq --no-deps {xformers} trl peft accelerate bitsandbytes triton --progress-bar off

# %%
import torch
from trl import SFTTrainer
from datasets import load_dataset
from transformers import TrainingArguments, TextStreamer
from unsloth.chat_templates import get_chat_template
from unsloth import FastLanguageModel, is_bfloat16_supported
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1863, in _LazyModule._get_module(self, module_name)
#    1862 try:
# -> 1863     return importlib.import_module("." + module_name, self.__name__)
#    1864 except Exception as e:
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_processing_utils.py:22
#      21 from .image_processing_base import BatchFeature, ImageProcessingMixin
# ---> 22 from .image_transforms import center_crop, normalize, rescale
#      23 from .image_utils import ChannelDimension, get_image_size
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_transforms.py:22
#      20 import numpy as np
# ---> 22 from .image_utils import (
#      23     ChannelDimension,
#      24     ImageInput,
#      25     get_channel_dimension_axis,
#      26     get_image_size,
#      27     infer_channel_dimension_format,
#      28 )
#      29 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_utils.py:65
#      64 if is_torchvision_available():
# ---> 65     from torchvision import io as torchvision_io
#      66     from torchvision.transforms import InterpolationMode
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\__init__.py:10
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\convnext.py:9
#       8 from ..ops.misc import Conv2dNormActivation, Permute
# ----> 9 from ..ops.stochastic_depth import StochasticDepth
#      10 from ..transforms._presets import ImageClassification
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\ops\__init__.py:23
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\ops\poolers.py:10
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      13 # copying result_idx_in_level to a specific index in result[]
#      14 # is not supported by ONNX tracing yet.
#      15 # _onnx_merge_levels() is an implementation supported by ONNX
#      16 # that merges the levels to the right indices
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\ops\roi_align.py:7
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\__init__.py:3
#       1 import torch
# ----> 3 from . import convert_frame, eval_frame, resume_execution
#       4 from .backends.registry import list_backends, lookup_backend, register_backend
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\convert_frame.py:33
#      32 from torch._dynamo.distributed import get_compile_pg
# ---> 33 from torch._dynamo.symbolic_convert import TensorifyState
#      34 from torch._guards import compile_context, CompileContext, CompileId, tracing
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\symbolic_convert.py:27
#      26 import torch._logging
# ---> 27 from torch._dynamo.exc import TensorifyScalarRestartAnalysis
#      28 from torch._guards import tracing, TracingContext
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\exc.py:11
#      10 from . import config
# ---> 11 from .utils import counters
#      14 if TYPE_CHECKING:
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\utils.py:65
#      64 import torch
# ---> 65 import torch._functorch.config
#      66 import torch.fx.experimental.symbolic_shapes
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_functorch\config.py:66
#      50 # When AOTAutograd regenerates aliased graph outputs,
#      51 # attempt to use functionalization's view-replay logic
#      52 # before falling back to the autograd engine's view replay or as_strided.
#    (...)
#      64 # once XLA pin update works,
#      65 # or default config to true and fix relevant bugs
# ---> 66 from torch._inductor.config import is_fbcode
#      69 # View replay is currently not compatible with AOTAutogradCache, since
#      70 # FunctionalTensors are not serializable. We'll need to make them
#      71 # serializable before enabling warm cache with this config turned on.
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_inductor\__init__.py:9
#       7 from typing import Any, Dict, List, Optional, Tuple, TYPE_CHECKING, Union
# ----> 9 import torch._inductor.config
#      10 import torch.fx
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_inductor\config.py:161
#     156 # register custom graph optimization pass hook. so far, pre/post passes are
#     157 # only applied before/after pattern_matcher in post_grad_passes.
#     158 #
#     159 # Implement CustomGraphPass to allow Inductor to graph compiled artifacts
#     160 # to which your custom passes have been applied:
# --> 161 post_grad_custom_pre_pass: torch._inductor.custom_graph_pass.CustomGraphPassType = None
#     162 post_grad_custom_post_pass: torch._inductor.custom_graph_pass.CustomGraphPassType = None
#
# AttributeError: partially initialized module 'torch._inductor' has no attribute 'custom_graph_pass' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\trl\import_utils.py:111, in _LazyModule._get_module(self, module_name)
#     110 try:
# --> 111     return importlib.import_module("." + module_name, self.__name__)
#     112 except Exception as e:
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\trl\trainer\sft_trainer.py:27
#      26 from packaging import version
# ---> 27 from transformers import (
#      28     AutoModelForCausalLM,
#      29     AutoTokenizer,
#      30     BaseImageProcessor,
#      31     DataCollator,
#      32     DataCollatorForLanguageModeling,
#      33     FeatureExtractionMixin,
#      34     PreTrainedModel,
#      35     PreTrainedTokenizerBase,
#      36     ProcessorMixin,
#      37     Trainer,
#      38     TrainingArguments,
#      39     is_wandb_available,
#      40 )
#      41 from transformers.trainer_callback import TrainerCallback
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1851, in _LazyModule.__getattr__(self, name)
#    1850 elif name in self._class_to_module.keys():
# -> 1851     module = self._get_module(self._class_to_module[name])
#    1852     value = getattr(module, name)
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1865, in _LazyModule._get_module(self, module_name)
#    1864 except Exception as e:
# -> 1865     raise RuntimeError(
#    1866         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1867         f" traceback):\n{e}"
#    1868     ) from e
#
# RuntimeError: Failed to import transformers.image_processing_utils because of the following error (look up to see its traceback):
# partially initialized module 'torch._inductor' has no attribute 'custom_graph_pass' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 2
#       1 import torch
# ----> 2 from trl import SFTTrainer
#       3 from datasets import load_dataset
#       4 from transformers import TrainingArguments, TextStreamer
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\trl\import_utils.py:102, in _LazyModule.__getattr__(self, name)
#     100 elif name in self._class_to_module.keys():
#     101     module = self._get_module(self._class_to_module[name])
# --> 102     value = getattr(module, name)
#     103 else:
#     104     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\trl\import_utils.py:101, in _LazyModule.__getattr__(self, name)
#      99     value = self._get_module(name)
#     100 elif name in self._class_to_module.keys():
# --> 101     module = self._get_module(self._class_to_module[name])
#     102     value = getattr(module, name)
#     103 else:
#
# File c:\Users\COMPUTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\trl\import_utils.py:113, in _LazyModule._get_module(self, module_name)
#     111     return importlib.import_module("." + module_name, self.__name__)
#     112 except Exception as e:
# --> 113     raise RuntimeError(
#     114         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     115         f" traceback):\n{e}"
#     116     ) from e
#
# RuntimeError: Failed to import trl.trainer.sft_trainer because of the following error (look up to see its traceback):
# Failed to import transformers.image_processing_utils because of the following error (look up to see its traceback):
# partially initialized module 'torch._inductor' has no attribute 'custom_graph_pass' (most likely due to a circular import)

# %% [markdown]
# ## 1. Load model for PEFT

# %%
# Load model
max_seq_length = 2048
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Meta-Llama-3.1-8B-bnb-4bit",
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    dtype=None,
)

# Prepare model for PEFT
model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    lora_alpha=16,
    lora_dropout=0,
    target_modules=["q_proj", "k_proj", "v_proj", "up_proj", "down_proj", "o_proj", "gate_proj"],
    use_rslora=True,
    use_gradient_checkpointing="unsloth"
)
print(model.print_trainable_parameters())

# %% [markdown]
# ## 2. Prepare data and tokenizer

# %%
tokenizer = get_chat_template(
    tokenizer,
    chat_template="chatml",
    mapping={"role" : "from", "content" : "value", "user" : "human", "assistant" : "gpt"}
)

def apply_template(examples):
    messages = examples["conversations"]
    text = [tokenizer.apply_chat_template(message, tokenize=False, add_generation_prompt=False) for message in messages]
    return {"text": text}

dataset = load_dataset("mlabonne/FineTome-100k", split="train")
dataset = dataset.map(apply_template, batched=True)

# %% [markdown]
# ## 3. Training

# %%
import os
os.environ['UNSLOTH_RETURN_LOGITS'] = '1'

trainer=SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
   # dataset_text_field="text",
   # max_seq_length=max_seq_length,
  #  dataset_num_proc=2,
  #  packing=True,
    args=TrainingArguments(
        learning_rate=3e-4,
        lr_scheduler_type="linear",
        per_device_train_batch_size=4,
        gradient_accumulation_steps=4,
        num_train_epochs=1,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        warmup_steps=10,
        output_dir="output",
        seed=0,
    ),
)

trainer.train()

# %% [markdown]
# ## 4. Inference

# %%
# Load model for inference
model = FastLanguageModel.for_inference(model)

messages = [
    {"from": "human", "value": "Is 9.11 larger than 9.9?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt",
).to("cuda")

text_streamer = TextStreamer(tokenizer)
_ = model.generate(input_ids=inputs, streamer=text_streamer, max_new_tokens=128, use_cache=True)

# %% [markdown]
# ## 5. Save trained model

# %%
model.save_pretrained_merged("model", tokenizer, save_method="merged_16bit")
model.push_to_hub_merged("mlabonne/FineLlama-3.1-8B", tokenizer, save_method="merged_16bit")

# %%
model.save_pretrained_gguf("model", tokenizer, "q8_0")
quant_methods = ["q2_k", "q3_k_m", "q4_k_m", "q5_k_m", "q6_k", "q8_0"]
for quant in quant_methods:
    model.push_to_hub_gguf("mlabonne/FineLlama-3.1-8B-GGUF", tokenizer, quant)
